# %% [markdown]
# # Merge, Join, and Concatenate

# %% [markdown]
# ![joins.png](attachment:joins.png)

# %%
import pandas as pd

# %%
# creating first dataframe

df1 = pd.read_csv(r"C:\Users\shass\my_github\my_practice_repository\pandas_for_beginners\datasets\LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
# creating second dataframe

df2 = pd.read_csv(r"C:\Users\shass\my_github\my_practice_repository\pandas_for_beginners\datasets\LOTR_2.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %% [markdown]
# ## Merge (most commonly used)

# %%
# 'df1' becomes our left df because we specify it first, by default calling the below will execute an 'inner join' i.e.
# where a value is in both tables based on values that appear in both tables

df1.merge(df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39
