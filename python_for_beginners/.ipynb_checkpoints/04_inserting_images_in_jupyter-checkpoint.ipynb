# %%
# first example uses markdown to insert an image

# %% [markdown]
# ![if_elif_else_statments_picture.png](attachment:if_elif_else_statments_picture.png)

# %%
# display an image from directory using code rather than markdown

from IPython.display import Image

# Provide the correct file path if the image is not in the same directory as the notebook
image_path = "if_elif_else_statments_picture.png"

# Display the image in the notebook
Image(image_path)
